# %% [markdown]
# # 2. [Python](https://www.python.org/)의 기본
# -------------------
#
# ## Python 프로그램 개요
# --------------------------
# * Python 프로그램의 소스 코드는 일련의 정의와 명령문으로 구성된다.
#
#
# * Python 프로그램이나 소스 코드는 스크립트 (script)라고도 불림.
#
#
# * 프로그램을 작성하는 사람이 command 혹은 statement라고 불리는 문장들을 작성하여, 이 문장들을 통해 Python 인터프리터가 프로그램 작성자의 목적에 맞는 일을 하도록 지시한다.
#
#
# * 다음은 print 문장을 이용한 간단한 프로그램이다.
#
#  * In [1]: 의 오른쪽의 내용이 우리가 작성하는 프로그램의 내용이며 그 다음 줄의 내용이 프로그램의 출력 결과이다.

# %% [markdown]
# #### 예제 2

# %%
# 22010703

x = input("학번을 입력하시오")
x = int(x)
if x > 20000000 :
    xx = (x-20000000)//100000
else : 
    xx = (x-10000000)//100000
print("당신은",xx,"학번 입니다.")
# Out:
# 학번을 입력하시오22010703
# 당신은 20 학번 입니다.

# %%
print('This is my first Python program.')
# Out:
# This is my first Python program.

# %% [markdown]
# ### 예제

# %%
# by 22010690
x = 21
if x%2 == 0:
    print("x is even number")
else:
    print("x is not even number")
# Out:
# x is not even number

# %%
#  by 22010707

hourly_wage = int(input("시급을 입력하시오(원) : "))
working_hour = int(input("주 근로 시간을 입력하시오 : "))
    
if working_hour > 50:
        bonus = input("양심껏 받고싶은 선물을 적으세용 ^^ : ")
        salary = hourly_wage * working_hour 
        print(salary, "+", bonus)
else :
        salary =  hourly_wage * working_hour
        print(salary)
# Out:
# 시급을 입력하시오(원) : 10000
# 주 근로 시간을 입력하시오 : 60
# 양심껏 받고싶은 선물을 적으세용 ^^ : 칼하트바지
# 600000 + 칼하트바지

# %% [markdown]
# ### 데이터 타입
#
# 프로그래밍에 사용되는 데이터들은 데이터 타입 (데이터 형)을 구분한다.
#
# Python에는 크게 세 가지 기본 데이터 타입이 존재하며 `type()` 함수로 확인할 수 있다.
# * [숫자](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex) (`int`, `float`)
#   * ```5```, ```10.3```, ```-2```, ```-1.02```
#   * 사칙연산 등을 수행할 수 있음
#   * 숫자형 데이터는 다시 정수형과 실수형으로 구분할 수 있다.
# * [문자열](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str) (`str`)
#   * ```"apple"```, ```"Hello, world!"```, ```'Yeungnam University'```, ```"15"```
#   * 큰 따옴표나 작은 따옴표로 표현
# * [부울, Boolean](https://docs.python.org/3/library/stdtypes.html#truth-value-testing) (`bool`)
#   * ```True```, ```False```
#
# 그 외에 리스트(`list`), 투플(`tuple`), 딕셔너리(`dict`) 등에 대해 공부할 것이다.

# %% [markdown]
# ### 수치와 연산
#
# * 숫자형 데이터에는 사칙연산이나 나머지, 제곱 등의 연산을 적용할 수 있다.
# * Jupyter의 코드 셀로 표현되는 IPython 콘솔은 마치 계산기처럼 이용 가능하다.

# %%
3 + 4
# Out:
# 7

# %%
3 - 4
# Out:
# -1

# %%
3 * 4
# Out:
# 12

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Python 2 :</b>
#
# * Python 2.x에서는 정수끼리 나누기 연산의 결과는 정수로 나타난다. 소수점 아래의 숫자는 버린다.
#   * 3/4의 결과는 0이며, 6/4의 결과는 1
# * Python 2.x에서는 나누기를 통하여 실수 결과를 얻고자 할 때는 연산되는 수를 실수형으로 먼저 바꾼 후 진행한다.
#     * ```3 / 4.0``` 혹은 ```3.0 / 4```
# </div>

# %% [markdown]
# Python 3.x에서는 정수끼리 나누기 연산의 결과는 실수로 나타난다.

# %%
3 / 4
# Out:
# 0.75

# %% [markdown]
# 만약 나누기의 정수 부분만 나타내려면 다음을 이용한다.

# %%
7 // 3
# Out:
# 2

# %% [markdown]
# 다음은 나머지 연산을 수행한다.

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# 제곱이나 거듭제곱은 ```**```를 이용한다. 다른 프로그램 언어에서는 제곱을 표현할 때 ```^```를 사용하는 경우가 많으므로, 혼동하지 않도록 주의한다.

# %%
5 ** 2
# Out:
# 25

# %%
2 ** 3
# Out:
# 8

# %%
2 ** (1/2)
# Out:
# 1.4142135623730951

# %%
10 ** (-1)
# Out:
# 0.1

# %% [markdown]
# 복잡한 연산의 순서는 기본적인 수학 규칙을 따른다.

# %%
2 + 2 * 2
# Out:
# 6

# %%
(3 - 5) * (6 + (2 - 4))
# Out:
# -8

# %% [markdown]
# ## 변수
#
# ------------------------
#
# <p> &#9635 <font color=#00008B> 변수 </font> - 데이터를 저장하고 나중에 재사용할 수 있도록 이름이 붙어 있는 값을 말한다. </p>
#
# * 변수는 컴퓨터 프로그래밍의 가장 기본적인 구성요소로 반드시 잘 이해해 두어야 한다.
# * 프로그램을 처음 시작하는 경우, 변수를 왜 사용해야 하는지 이해하기 힘든 경우도 있으니, 주의깊게 아래 내용을 살펴보자.
#
#
#
# 계산을 하다보면 특정 변수를 생성하여 값을 지정하고 변수를 통하여 수식을 계산하는 것이 더 편리할 경우가 많다.
#   * 수학 문제를 풀 때, $x$나 $y$와 같은 변수 기호를 이용하여, 문제를 더 간결하게 표현하는 것과 비슷한 원리이다.

# %% [markdown]
# ### 변수 생성의 기본 방법
#
# * 수학에서 $x=10$과 같이 변수와 그 값을 지정하듯이 Python에서도 등호(```=```)를 이용하여 변수의 값을 지정한다.
# * 변수의 이름, 변수명은 기본적인 규칙을 지키는 선에서 마음대로 지어주면 된다.
#    * 이 규칙에 대해서는 잠시 후에 살펴본다.
# * 대입 연산에서는 반드시 왼쪽에 변수명이 등장한다.

# %% [markdown]
# <p> &#9635 <font color=#00008B> 정수형 변수 지정 </font> </p>
#
#  * 다음을 '`my_integer`는 10과 같다'고 해석을 해서는 안 된다. '`my_integer`에 10을 대입한다'와 같이 해석한다.
#
#  * 정의된 변수를 코드 셀에 다시 타이핑하여 값의 내용을 출력하도록 하였다.

# %%
my_integer = 10
my_integer
# Out:
# 10

# %% [markdown]
# <p> &#9635 <font color=#00008B> 실수형 변수 지정 </font> </p>

# %%
my_number = 5.2

# %%
my_number
# Out:
# 5.2

# %% [markdown]
# <p> &#9635 <font color=#00008B> 문자열 변수 지정 </font> </p>

# %%
my_string = "Statistics"
my_string
# Out:
# 'Statistics'

# %% [markdown]
# <p> &#9635 <font color=#00008B> 부울형 (Boolean) 변수 지정 </font> </p>

# %%
my_bool = True
my_bool
# Out:
# True

# %%
my_bool2 = False
my_bool2
# Out:
# False

# %%
my_integer2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_integer2
#
# NameError: name 'my_integer2' is not defined

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>에러:</b>
#     존재하지 않는 변수, 위에서는 <code>my_integer2</code>를 사용하려고 하면 NameError가 발생한다.
# </div>

# %% [markdown]
# 앞의 예제들처럼 대입 연산의 오른쪽에는 상수값이 오거나, 다음의 예제들처럼 기존의 변수 혹은 기존의 변수를 이용한 식 등이 올 수 있다.

# %%
my_second_integer = my_integer + 1
my_second_integer
# Out:
# 11

# %%
width = 10
height = 13
rectangle_area = width * height
rectangle_area
# Out:
# 130

# %% [markdown]
# ### 변수와 객체
#
# * Python에 존재하는 거의 모든 것들은 객체 (object)라는 형태로 존재한다.
#   * 숫자, 문자열, 리스트, dictionary, ndarray, function 등이 있으며, 이 과목을 통해 자세히 살펴볼 것이다.
# * 변수는 이러한 객체들에 이름을 붙여, 추후에 참조하여 더 복잡한 연산에 사용할 수 있도록 하는 역할을 한다.
#   * 객체는 데이터의 실질적인 존재, 변수 혹은 변수명은 그 존재를 지칭하는 이름이라고 생각하자.

# %% [markdown]
# <img src="https://github.com/ksublee/SPuP/blob/master/figure/variable_obejct.png?raw=true" width="400">

# %% [markdown]
# ### 변수명 규칙
#
# * Python 변수명은 문자나 _로 시작
#   * ```_the_string```
#   * ```my_variable```
# * 첫 글자가 아닌 나머지 부분은 문자, 숫자, `_`가 올 수 있음
#   * ```password1```
#   * ```n00b```
#   * ```un_der_score```
# * 대소문자 구별 : ```X```와 ```x```는 서로 다른 변수

# %% [markdown]
# 변수명을 짓는 방법
#
#  * 알아보기 쉽게 짓는다.
#    * ```interestrate``` -> ```interest_rate```
#      * 소문자와 밑줄을 이용한 이런 표기법을 snake case라고 한다.
#    * 반면 (나중에 공부할) 클래스의 이름은 PerfectTool과 같이 각 단어의 첫 글자를 대문자로 하는 것이 보통이다.
#      * Pascal case 혹은 camel case라고 한다.
#  * 무슨 변수를 나타내는지 이해할 수 있도록 짓는다.
#    * ```abcdefg``` : 아무 의미 없어 보이며 이렇게 짓지 않음
#    * ```average_num_students``` : 변수명이 다소 긴 것처럼 느껴지지만, 학생 수의 평균을 의미하는 변수임을 추측할 수 있음

# %% [markdown]
# ### 변수 지정에 있어 Python의 특징
#
# * 많은 다른 프로그래밍 언어의 경우 변수형을 따로 선언해 주어야 함. 예를 들어, C언어 등의 경우
#   * `int n = 10`
#     * 정수(integer)형 변수
#   * `double x = 2.12`
#     * double precision을 가지는 실수형 변수
#   * `char c = 'a'`
#     * 문자(character)형 변수
# * Python은 int, double, char 등과 같은 변수형에 대한 키워드(keyword)를 따로 선언해 주지 않는다.
#   * 프로그래머는 변수형을 일일이 입력할 필요가 없으니 편리한 점이 있음

# %% [markdown]
# ### Dynamic types
#
# * Python에서는 데이터 type을 따로 명시하는 것이 아니기 때문에, 프로그램 중간에 데이터 type이 바뀔 수 있다.
#   * `x = 10`
#     …
#
#     `x = 'John'`
#
#     …
#
#     `x = True`
#
#
# * 그러나, 하나의 변수가 한 프로그램 내에서 데이터 타입이 변하는 것은 바람직하지 않으며, 동일한 데이터 타입을 유지하도록 한다.
#
# * 반면 변수의 값은 계속 변할 수 있다.

# %% [markdown]
# ### 변수값 재지정
#
# 한 번 지정한 변수값을 얼마든지 새 변수값으로 바꿀 수 있음

# %%
a = 1
a = 2
a = 2.1
b = "Hi"
b = "Hello"
c = True
c = False

# %% [markdown]
# 다음의 예제에서는 ```area```의 값이 ```radius```의 값에 따라 바뀐다.

# %%
pi = 3
radius = 11
area = pi * (radius ** 2)
print(area)
# Out:
# 363

# %%
radius = 12
area = pi * (radius ** 2)
print(area)
# Out:
# 432

# %% [markdown]
# ### Multiple assignment
#
# Python에서는 다음과 같이 여러 개의 변수에 여러 값들을 한 번에 지정할 수 있다.
# * 첫 라인에서는 ```x```에 2를, ```y```에 3을 대입하고,
# * 다음 라인에서 ```x```에 ```y```의 값인 3을, ```y```에 ```x```의 값인 2를 다시 재지정한다.

# %%
x, y = 2, 3   # x에는 2를 대입하고, y에는 3을 대입한다.
x, y = y, x   # x에는 기존 y의 값을, y에는 기존 x의 값을 대입.
print('x = ', x)
print('y = ', y)
# Out:
# x =  3
# y =  2

# %% [markdown]
# ## 주석 (comment)
#
# <p> <font color=#00008B> &#9635 주석 </font> - 주석은 코드의 설명으로, 프로그램을 실행시켰을 때 실행되지 않는 부분이다.
#
# * 한 줄로 주석 넣기, #으로 시작
#   * ```# This code solves the P vs NP problem.```
# * 여러 줄에 걸쳐 주석을 넣을 때, ```"""```를 이용
#   * ```
#     """
#     Turing used this code to crack Enigma.
#     With this code, anybody can hack a server like a pro.
#     """
#     ```

# %% [markdown]
# ## 간단한 입출력 연습
# -------------------------------------------
#
# ### 문자열 (string) 출력해 보기
#
# 프로그래밍의 가장 기본 예제를 연습해 보자. Python은 인터프리터 언어로서 매우 간단하게 Hello world 프로그램을 작성할 수 있다.
# * 이 때, [```print()```](https://docs.python.org/3/library/functions.html#print)라는 명령이 사용된다.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# 위 예제에서 따옴표로 둘러싸여 있는 부분은 문자열을 의미하며 print 명령을 통해 해당 문자열 - 여기서는 Hello, world! - 을 화면에 출력하라는 뜻이다.
# * 문자열을 생성할 때는 따옴표로 해당 문자열을 감싸준다.
#   * 큰 따옴표, 작은 따옴표 모두 가능
# * Python 2.x에서는 ```print``` 명령에 괄호 생략 가능
# * Python 3.0 이상에서는 ```print```가 함수로 변경되었기 때문에, 반드시 괄호를 이용해야 한다.
# * https://docs.python.org/3/whatsnew/3.0.html#print-is-a-function

# %%
print(Hello, world!)
# Out:
#   Cell In[29], line 1
#     print(Hello, world!)
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>에러:</b> 문자열을 사용할 때, 문자열 기호 <code>"</code> 혹은 <code>'</code>를 생략하면 당연히 에러가 발생하니 주의하자.
# </div>

# %% [markdown]
# ### 변수의 내용 출력하기
#
# 문자열 뿐만 아니라, 변수의 내용, 즉, 변수가 지칭하는 객체 (object)의 내용을 화면에 출력할 수 있다.
#  * 이 때는 ```print``` 함수의 괄호 안에 원하는 변수명을 입력한다.

# %%
width = 10
height = 13
rectangle_area = width * height
print(rectangle_area)
# Out:
# 130

# %% [markdown]
# 물론 앞에서 연습하였듯이, 변수 하나의 내용을 확인할 때는 굳이 ```print``` 함수를 사용하지 않아도 화면에 출력할 수 있다.

# %%
rectangle_area
# Out:
# 130

# %% [markdown]
# Jupyter notebook에서 여러 변수를 한 번에 확인하고 싶을 때는 ```print``` 함수를 이용하는 것이 낫다.

# %%
print(width)
print(height)
print(rectangle_area)
# Out:
# 10
# 13
# 130

# %% [markdown]
# ```print```문을 생략한다면 마지막 변수의 내용만 확인할 수 있다. 따라서, 확실하게 화면에 프린트하고 싶은 경우라면 ```print``` 함수를 적극적으로 이용하는 것이 좋다.

# %%
width
height
rectangle_area
# Out:
# 130

# %% [markdown]
# 여러 값을 확인하려면, 다음과 같이 투플로 표현하여 출력할 수 있다.

# %%
width, height, rectangle_area
# Out:
# (10, 13, 130)

# %% [markdown]
# 혹은 다음을 노트북의 가장 위에 설정 한 후에 여러 변수를 출력하게 할 수 있다.
# [`InteractiveShell.ast_node_interactivity`](https://ipython.readthedocs.io/en/stable/config/options/terminal.html)의 default option은 `last_expr`이다.
#
# ```
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = 'all'
# ```

# %% [markdown]
# <div class="alert alert-info">
#
# `print(variable)`은 ```print(str(variable))```와 동치이고, 코드 셀에 ```variable```이름만을 입력하여 출력하도록 하는 것은 ```print(repr(variable))```와 동치이다.
#
# `str()`은 보다 읽기 쉬운 형태로 출력하는 것을 목표로 하고, `repr()`은 보다 공식적인 표현을 출력하도록 한다.
# </div>

# %% [markdown]
# ### 문자열 입력 받기
#
# [```input()```](https://docs.python.org/3/library/functions.html#input) 함수를 사용하여 콘솔로부터 문자열을 입력 받을 수 있음
#
# * python 2.x에서는 ```raw_input()``` 함수를 이용한다.
#
# 아래 예제는 간단해 보이지만, 처음 겪는 사람은 다소 헷갈리 수 있다.
#
# 아래의 명령을 실행하면, 키보드 입력을 기다리는 화면이 나타난다.
# * 자유롭게 타이핑을 한 후 엔터를 치고 결과를 확인해 보자.

# %%
input_string = input("Input any string : ")
# Out:
# Input any string :  ABCD EFG HIJK LMNO

# %% [markdown]
# * 위 코드에서 ```"Input any string : "``` 부분은 콘솔 창에 다시 한 번 나타나는 부분으로 원하는 대로 바꾸어 쓸 수 있음
#   * 입력할 문자열에 대한 적당한 설명을 작성하는 곳이라고 이해하면 좋다.
#   * 프로그래머가 문자열을 입력 받는 목적을 입력하는 사람에게 설명할 수 있는 부분이라고 생각하자.
# * 콘솔에서 입력받은 문자열은 대입 연산자(=) 왼쪽의 변수 이름으로 저장된다.
#   * 위 예제에서는 "ABCD EFG HIJK LMNOP"라는 문자열을 임의로 입력하였다.
#   * 입력 받는 변수 이름은 ```input_string```
# * ```print``` 명령을 이용하여 ```input_string``` 저장된 내용을 다시 출력해 보자.
#   * 임의로 입력한 "ABCD EFG HIJK LMNOP"가 다시 출력됨을 알 수 있다.

# %% [markdown]
# <img src="https://github.com/ksublee/SPuP/blob/master/figure/input.png?raw=true" width="450">

# %%
print(input_string)
# Out:
# ABCD EFG HIJK LMNO

# %% [markdown]
# 다시 한 번 연습해 보자.
#  * 아래 예제에서는 "Kyungsub Lee"라는 이름을 입력하여 ```name```이라는 변수에 전달할 수 있도록 하였다.

# %%
name = input("Please input your name correctly : ")
# Out:
# Please input your name correctly :  Kyungsub Lee

# %% [markdown]
# ```name```의 내용을 다시 출력하여, 입력이 성공적으로 진행되었는지 확인하자.

# %%
print(name)
# Out:
# Kyungsub Lee

# %% [markdown]
# ## `True`와 `False`
# ----------------------------------------
#
# ### 부울 (Boolean)형 혹은 논리형 자료
#
# * ```True``` 혹은 ```False```로 구성된 자료형이다.
# * Boolean type의 변수는 프로그래밍에서 중요한 역할을 담당한다.
#   * 특히 조건에 따라 처리를 달리하는 프로그램을 작성할 때 유용하다.

# %%
2 < 0.9
# Out:
# False

# %%
3 > -3
# Out:
# True

# %% [markdown]
# 변수에 ```True``` 혹은 ```False```를 대입할 수 있다.

# %%
# True의 값을 가지는 변수 a
a = True
print(a)
# Out:
# True

# %%
# False의 값을 가지는 변수 b
b = False
b
# Out:
# False

# %% [markdown]
# ### Boolean 연산 : `and`, `or`, `not`
#
#
# | `A` | `B` |  `A and B` | `A or B` | `not A` |
# |---|---|---------|--|---|
# True | True | True | True | False |
# True | False| False | True | False |
# False | True |  False | True | True |
# False | False |  False | False | True |

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ```not```, ```and```, ```or```의 순서로 진행한다. 괄호가 있을 경우에는 괄호 안의 것을 먼저 계산한다.

# %%
False and True or True
# Out:
# True

# %%
# 괄호가 있을 경우 괄호 안의 내용을 먼저 연산한다.
False and (True or True)
# Out:
# False

# %%
not False or True
# Out:
# True

# %%
not (False or True)
# Out:
# False

# %% [markdown]
# ## 비교연산과 대입연산
#
# -----------------------------------------
#
# <p> <font color=#00008B> &#9635 대입연산 </font> - 등호를 하나만 사용하는 경우, <code>=</code>, 이를 대입연산자라 한다. </p>
#
# 아래에서 ```x```라는 변수에 5라는 정수를 대입한다.

# %%
x = 5

# %% [markdown]
# <font color=#8B0000>  따라서 ```4=4```와 같은 문장은 잘못된 문장이다. </font>
#   * 숫자 4에 4를 대입할 수 없음.

# %%
4 = 4
# Out:
#   Cell In[58], line 1
#     4 = 4
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# <p> <font color=#00008B>  &#9635 비교연산 </font> - 등호를 두 개를 연속해서 사용하는 경우, <code>==</code>, 비교연산이라 한다. 이것 외에도 다양한 비교연산이 있다.  </p>
#
# 아래 예제에서는 숫자 4와 숫자 4가 같은지 비교하고 있다. 당연히 같으므로 결과는 ```True```이다.

# %%
4 == 4
# Out:
# True

# %%
4 == 4.0
# Out:
# True

# %% [markdown]
# 아래 예제에서는 "Korea"라는 문자열과 "Japan"이라는 문자열이 같은지 비교하고 있다. 당연히 다르므로 결과는 ```False```이다.

# %%
"Korea" == "Japan"
# Out:
# False

# %%
# 대소문자가 달라도 다른 문자열이다.
"korea" == "KOREA"
# Out:
# False

# %%
" korea" == "korea"
# Out:
# False

# %% [markdown]
# 아래 예제에서는 ```c```라는 변수에 ```False```라는 값을 대입한 후, 변수 ```c```의 내용과 값 ```False```가 같은지 비교하고 있다. 두 값이 같으므로 결과는 ```True```이다.

# %%
c = False
c == False
# Out:
# True

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>주의:</b> =와 ==의 차이는 프로그램 초보자들이 빈번히 혼동하는 부분이다. 연습을 통해 잘 숙지하도록 한다.
# </div>

# %% [markdown]
# ### 대입연산 예제
#
# 다음의 결과들을 순차적으로 생각해 보자. 항상 오른쪽의 계산을 완료하여 왼쪽의 변수에 대입하도록 한다.

# %%
x = 2
x = x + 4  # 더하기
x = x * x  # 곱하기
x = x % 5  # 나머지

# %%
print(x)
# Out:
# 1

# %% [markdown]
# ### 비교연산
#
# <p> &#9635 <font color=#00008B> 비교연산의 종류 </font> </p>
#
#
# | 비교연산자 | 대응되는 수학기호 |
# |:----------:|:--------------:|
# | `>` | $>$ |
# | `>=` | $\geq$ |
# |`<` | $<$ |
# |`<=` | $\leq$ |
# | `!=` | $\neq$ |
# | `==` | $=$ |
#
#
# 비교연산자를 사용한 식이 옳을 경우 ```True```를, 그렇지 않을 경우 ```False```를 반환한다.

# %%
egg = 138
spam = 370

# %%
egg == spam
# Out:
# False

# %%
egg != spam
# Out:
# True

# %%
name = 'Kim'
name != 'Lee'
# Out:
# True

# %% [markdown]
# ### 복합대입연산자 (Compound assignment operator)
#
# <p> <font color=#00008B> &#9635  복합대입연산자 </font> -  <code>+=, -=, *=, /=, %= </code> </p>
#
# 변수에 값을 할당하면서, 변수의 값을 변경하는 연산자로 연산과 대입을 동시에 할 수 있음. 다음의 코드에서
#
# * ```i += 3``` 는 ```i = i + 3``` 과 같고
# * ```j -= 0.5``` 는 ```j = j - 0.5``` 과 같다.
# * ```m *= 10``` 는 ```m = m * 10``` 과 같고,
# * ```n /= 5``` 는 ```n = n / 5``` 과 같다.

# %%
i = 1
i += 3  # i = i + 3
i
# Out:
# 4

# %%
j = 10
j -= 0.5  # j = j - 0.5
j
# Out:
# 9.5

# %%
k = 2
k *= 4  # j = k * 4
k
# Out:
# 8

# %%
m = 2
m *= 10
m
# Out:
# 20

# %%
n = 20
n /= 5
n
# Out:
# 4.0

# %%
s = "abcd"
s += "e"
s
# Out:
# 'abcde'

# %% [markdown]
# ## 파이썬 스타일 가이드
#
# https://www.python.org/dev/peps/pep-0008/

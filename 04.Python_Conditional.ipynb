# %% [markdown]
# # 4. 조건문
# --------------------------------------------

# %% [markdown]
# ## `if-else` 구문
#
# ### Statement
#
# Python interpreter가 실행 가능한 문법에 옳은 문장들을 statement라 한다.
# 앞 장에서 공부한 statement들과 더불어 조건문과 반복문을 공부해 보자.
#
# * ```1 + 2```
# * ```x = 7```
# * ```print("Hello")```
# * ```newstring = "ABCD".lower()```
# * 조건문
# * 반복문

# %% [markdown]
# ### 조건문
#
# 프로그래머가 명시한 ```if```의 조건이 ```True```인가 ```False```인가에 따라 실행하는 문장(statement)이 달라지는 구문
#  * 테스트 구문은 항상 ```True``` 혹은 ```False```로 계산된다.
#
#
#  * ```if```절의 다음에는 만약 테스트 결과가 ```True```일 경우 실행될 코드 블록이 나타난다.
#     * 만약 테스트 구문이 ```False```로 판명나면 실행하지 않는다.
#
#
#  * 추가적으로 만약 테스트 구문이 ```False```일 때 할 일을 나타낼 수 있다.
#     * 이에 해당되는 코드는 ```else``` 혹은 ```elif```의 구문에서 나타난다.
#
# <p style="text-align: center;">
# <img src="https://github.com/ksublee/SPuP/blob/master/figure/if.png?raw=true" width="250" height="175" />
# </p>
# 그림 출처 : Introduction to Computation and Programming Using Python, John V. Guttag

# %% [markdown]
# ### ```if else``` 문의 문법 구조
#
# <p> &#9635 문법 - 구문의 기본적인 구조는 다음과 같다.</p>
#
# ```
# if 조건문:
#   조건문 결과가 True일 경우 해야 할 일
# else:
#   조건문 결과가 False일 경우 해야 할 일
# ```

# %%
x = 15
if x % 2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Odd

# %% [markdown]
# <p style="text-align: center;">
# <img src="data:image/png;base64,..." width="450" alt="" /> </p>

# %%
#22210636
x = input("숫자를 입력하세요: ")
x = int(x)
if x % 2== 0:
    print("x는 2의 배수이다.")
else:
    print("x는 2의 배수가 아니다.")
# Out:
# 숫자를 입력하세요: 12
# x는 2의 배수이다.

# %% [markdown]
# 조건문 ```x % 2 == 0``` (x를 2로 나눈 나머지가 0인가)의 연산결과가 ```True```이면
# * ```print('Even')```을 실행
#
# ```False```이면
# * ```print('Odd')```을 실행

# %% [markdown]
# <p> &#9635 주의점 </p>
#
# * ```if```의 조건문과 ```else```의 뒤에 ```:```를 붙인다.
#
#
# * ```if```문은 test 조건문이 ```True```일 경우에 실행되는 코드 블록을 포함함.
#
#
# * ```else``` 문은 ```if``` 문에있는 조건식이 ```0``` 또는 ```False``` 값으로 해석될 때 실행되는 코드 블록을 포함함.
#
#
# * ```if```문과 ```else```의 내용은 들여쓰기 (indentation)를 해야 함.
#
#
# * 하나의 ```if```에 대응되는 ```else```는 한 개 혹은, 필요가 없을 경우 ```else``` 문은 생략 가능

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE: </b> 코드가 간단할 경우, 줄을 바꿔 들여쓰기를 하지 않고, 다음과 같은 문법도 가능
#
# ```
# if 조건문: 조건문 결과가 True일 경우 해야 할 일
# else: 조건문 결과가 False일 경우 해야 할 일
# ```
#
# </div>

# %%
my_age = 25
if my_age >= 20: print("get drunk")
else: print("not this time")
# Out:
# get drunk

# %% [markdown]
# # 예제 2

# %%
# by s21910680
my_age = 17
if my_age >= 20: print("get drunk")
else: print("not this time")
# Out:
# not this time

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE:</b> <code>else</code> 이후의 내용이 필요 없을 경우 <code>else</code>와 그 이하 부분은 생략 가능

# %%
my_status = 'dirty'
if my_status == 'dirty':
    print("take a shower")
    print("do a laundry")
# Out:
# take a shower
# do a laundry

# %%
my_status = 'clean'
if my_status == 'dirty':
    print("take a shower")
    print("do a laundry")

# %% [markdown]
# #### 들여쓰기 - indentation
# * C/C++이나 JAVA와 같은 언어에서는 들여쓰기는 코드를 보기 좋게 만들기 위한 것일 뿐 필수적인 것은 아님
# * Python에서는 들여쓰기가 문법의 일부이므로 **반드시 지키도록 한다**.
# * 따라서 다음은 바로 위의 코드와는 다르게 작동한다.

# %%
my_status = 'clean'
if my_status == 'dirty':
    print("take a shower")
print("do a laundry")
# Out:
# do a laundry

# %% [markdown]
# <p> &#9635 간단한 예제: </p>

# %%
if 3 < 4: print("if")
else: print("else")
# Out:
# if

# %%
if "3" < "4": print("if")
else: print("else")
# Out:
# if

# %%
x, y = 3, 3
if x = y:  # 잘못된 문법
    print("x is equal to y.")
else:
    print("x is different from y.")
# Out:
#   Input In [1]
#     if x = y:  # 잘못된 문법
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-danger"> <b>Error</b> 조건문에서 두 값이 같은지 비교할 때는 <code>==</code> 를 이용해야 한다. </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"> 주의 : 다음 두 코드의 차이점을 잘 살펴보자. </div>

# %%
x = 1
if x > 0:
    x = x - 2
else:
    x = x + 2
print(x)
# Out:
# -1

# %%
x = 1
if x > 0:
    x = x - 2
if x <= 0:
    x = x + 2
print(x)
# Out:
# 1

# %% [markdown]
# <p> &#9635 예제 : 조건문 안에 <code>and</code>를 이용하여 여러 조건을 검사 </p>

# %%
x = 3
y = 7
if x < y and x < 0: print("if")
else: print("else")
# Out:
# else

# %%
x = 3
y = 7
if x < y or x < 0: print("if")
else: print("else")
# Out:
# if

# %% [markdown]
# <p> &#9635 <code>and</code>를 이용할 때 흔히 하는 실수: </p>
#
# 주어진 ```x```가 ```y```보다도 크고, ```z```보다도 큰 지 검사하고 싶을 때

# %%
### 잘못된 예제
x, y, z  = 10, 2, 11
if x > y and z:
    print("x is larger than both y and z.")
else:
    print("x is less than or equal to one of y or z.")
# Out:
# x is larger than both y and z.

# %% [markdown]
# ```and```의 양쪽에는 ```True``` 혹은 ```False```가 판별되는 정확한 문장이 와야 한다.

# %%
x, y, z  = 10, 2, 11
if x > y and x > z:
    print("x is larger than both y and z.")
else:
    print("x is less than or equal to one of y or z.")
# Out:
# x is less than or equal to one of y or z.

# %% [markdown]
# <p> &#9635 예제 : <code>input()</code> 함수와 결합한 예제 </p>

# %%
answer = input("In Python, = is used for equality comparison, right? Yes or No >> ").lower()

if answer == "no" :
    print("You have cleared the test.")
else :
    print("You have failed the test.")

print("Thanks!")
# Out:
# In Python, = is used for equality comparison, right? Yes or No >>  no
# You have cleared the test.
# Thanks!

# %%
##by 21910680
score= int(input("통프 성적을 입력하시오"))
if score > 50:
    print ("잘했어요")
else:
    print ("조금 더 공부해보아요")
# Out:
# 통프 성적을 입력하시오0
# 조금 더 공부해보아요

# %% [markdown]
# #### 예제1

# %%
##by 22010687
print("안녕하세요. 저는 김상현의 몸무게 상태를 판별해주는 프로그램입니다.")

weight = int(input("김상현의 몸무게를 작성하세요:"))

if weight <50 :
    print("상현아... 몸무게가 왜 그래... 힘든 일 있어? 국립정신건강센터 번호는 (02) 2204-0114 입니다..!")
elif weight < 70 :
     print("오우! 날씬하네요! 멋지다 상현아!")
elif weight < 100 :
     print("돼지입니다. 하지만 괜찮습니다! 지금부터 열심히 운동하세요! ")
else :
    print("쌉돼지입니다. 운동 좀 하세요!!! 과체중은 성인병의 원인입니다!! ")
# Out:
# 안녕하세요. 저는 김상현의 몸무게 상태를 판별해주는 프로그램입니다.
# 김상현의 몸무게를 작성하세요:12
# 상현아... 몸무게가 왜 그래... 힘든 일 있어? 국립정신건강센터 번호는 (02) 2204-0114 입니다..!

# %% [markdown]
# ## 예제 2

# %%
#by 22013214

a=int(input("이 과제를 하는 날짜를 입력하세요. 예시: 5월 31일 -> 531"))

if a < 401 :
    print("훌륭해요! 부지런한 학생이네요.")
    
elif a < 501 :
    print("그래도 숙제가 있었다는 걸 잊지 않으셨군요!")
    
elif a < 601 :
    print("숙제를 제출해서 다행이에요.")
    
else: 
    print("저런.. HW1 점수는 0점입니다.")
# Out:
# 이 과제를 하는 날짜를 입력하세요. 예시: 5월 31일 -> 531531
# 숙제를 제출해서 다행이에요.

# %% [markdown]
# ## 예제 2

# %%
##by 22010689
print("시험공부를 열심히 하셧나요?")

score=int(input("당신의 시험점수:"))
if 0<=score<30:
    print("지금이라도 다른 진로를 찾아보세요.")
elif 30<=score<70:
    print("조금만 더 힘내봅시다.")
elif score>100 or score<0:
    print("올바른 값을 입력하세요.")
else:
    print("열심히 하셧네요,잘하셧어요.")
# Out:
# 시험공부를 열심히 하셧나요?
# 당신의 시험점수:-20
# 올바른 값을 입력하세요.

# %% [markdown]
# <p> &#9635 다음의 예제에서는 파일의 확장자가 .csv, .tsv, .txt일 경우 올바른 파일 형식으로 간주하고, 그렇지 않으면 잘못된 형식이라고 출력한다. </p>

# %%
filename = "mydata.csv"
if filename.endswith(".csv") or filename.endswith(".tsv") or filename.endswith(".txt") :
    print("Right file format")
else :
    print("Wrong file format")
# Out:
# Right file format

# %% [markdown]
# ### 예제 2

# %%
sum = 'ddd'

if sum =='good':
    print("잘했어요")
else:
    print("못했어요")
# Out:
# 못했어요

# %% [markdown]
# #### 예제
#
# 다음의 예제에서는 `username`에 따라 `print`의 결과가 달라지는 간단한 예제이다.

# %%
# by s20000000
username = "guest"

if username == "admin":
    print("Welcome, administrator!")
elif username == "guest":
    print("Welcome, guest.")
else:
    print("Unknown user.")
# Out:
# Welcome, guest.

# %% [markdown]
# #### 예제
#
# 입력한 해가 몇년대인지 결과가 나오는 예제이다.

# %%
#by s21810674
num = input("input year : ")
num=int(num)

if num >= 2020: print("2020s")
elif num >= 2010: print("2010s")
elif num >= 2000: print("2000s")
else: print("before 2000s")
# Out:
# input year : 2018
# 2010s

# %% [markdown]
# #### 예제2

# %%
# by s21810677
age = int(input("나이를 입력해주세요 : "))

if age < 20 :
    print("미성년자 입니다")
else :
    print("성인 입니다.")
# Out:
# 나이를 입력해주세요 : 25
# 성인 입니다.

# %% [markdown]
# #### 예제2

# %%
#by s22213028

grade = int(input("성적을 입력하세요 :"))

if grade >= 90:
    print("A 학점 입니다")
    print("참 잘했어요")
elif grade >=80:
    print ("B 학점 입니다")
elif grade >= 70:
    print ("C학점 입니다")
else :
    print ("공부 열심히 합시다")

# %% [markdown]
# ####  예제2

# %%
# by s22110664
a = int(input("A:"))
b = int(input("B:"))
c = int(input("C:"))

if a**2==b**2+c**2 or b**2==a**2+c**2 or c**2==a**2+b**2:
    print("직각삼각형")
else:
    print("일반삼각형")
# Out:
# A:3
# B:4
# C:5
# 직각삼각형

# %%
# by s20000000
s = "a"
if len(s) == 1:
    print("length one")
else:
    print("not length one")

# %% [markdown]
# ####  예제2

# %%
# by s21810632

x = int(input("x좌표를 입력하시오 : "))
y = int(input("y좌표를 입력하시오 : "))

if x>0 and y>0:
    print("제1사분면")
elif x<0 and y>0:
    print("제2사분면")
elif x<0 and y<0:
    print("제3사분면")
else:
    print("제4사분면")

# %%
# by 22010721
# 자판기 거스름돈 내주는 프로그램

my_money = int(input("자판기에 넣을 돈을 입력하시오 : "))

if my_money < 500:
    print("%d원을 돌려드립니다. 돈 들고 오세요" %my_money)
elif my_money == 500:
    print("%d원 상품을 선택하세요" %my_money)
elif my_money > 500:
    print("%d원을 돌려드립니다. 돈이 많으시네요" %(my_money-500))
# Out:
# 자판기에 넣을 돈을 입력하시오 : 880
# 380원을 돌려드립니다. 돈이 많으시네요

# %% [markdown]
# #### 예제2

# %%
# by s22110662
age = input("몇년생이신가요? : ")
age=int(age)

if  1981 < age <= 1996: 
    print("M-세대")
elif 1997 < age <= 2012:
    print("Z-세대")
else: print("MZ-세대")
# Out:
# 몇년생이신가요? : 2000
# Z-세대

# %%
# by s21810656

print("알파벳 자음 모음 판별")

alphabet = input("영어 알파벳을 입력하세요: ")

if alphabet.lower() in 'aeiou':
    print(f"{alphabet}은(는) 모음입니다!")
else:
    print(f"{alphabet}은(는) 자음입니다!")
# Out:
# 알파벳 자음 모음 판별
# 영어 알파벳을 입력하세요: a
# a은(는) 모음입니다!

# %% [markdown]
# #### 예제2

# %%
# by s22010399
print("권장 수면 시간 알아보기")
age = input("내 나이 : ")
age=int(age)

if  age <= 2: 
    print("권장 수면 시간 11~14시간")
elif 2 < age <= 5:
    print("권장 수면 시간 10~13시간")
elif 5 < age <= 13:
    print("권장 수면 시간 9~11시간")
elif 13 < age <= 17:
    print("권장 수면 시간 8~10시간")
elif 17 < age <= 64:
    print("권장 수면 시간 7~9시간")    
else: print("권장 수면 시간 7~8시간")
# Out:
# 권장 수면 시간 알아보기
# 내 나이 : 24
# 권장 수면 시간 7~9시간

# %%
#22010701 정민교 
s = "a"
if len(s)==1:
    print("length one")
else: 
    print("not length one")
# Out:
# length one

# %% [markdown]
# ### 예제2

# %%
#by 22210635
x,y,z= 9,4,15
if x>y and x>z:
    prnit("x is larger than both y and z")
else:
    print("x is less than or equal to one of y or z")
# Out:
# x is less than or equal to one of y or z

# %% [markdown]
# #### 예제
#
# 다음의 예제에서는 ```username``` 에 따라 ```print``` 의 결과가 달라지는 간단한 예제이다.

# %%
# by s22210612
username = 'guest'

if username == 'admin':
    print('Welcome, administrator!')
elif username == 'guest':
    print('Welcome, guest.')
else:
    print('Unknown user.')
# Out:
# Welcome, guest.

# %% [markdown]
# # 예제2

# %%
# by 22210619
kg = input("몸무게 : ")
cm = input("키 : ")

weight = float(kg)
height = float(cm)
BMI = weight/(height/100)**2

if BMI < 18.5:
    print("저체중")
elif BMI >= 18.5 and BMI <= 22.9:
    print("정상체중")
elif BMI >= 23.0 and BMI <= 24.9:
    print("과체중")
elif BMI >= 25.0 and BMI <= 29.9:
    print("경도비만")
elif BMI >= 30.0 and BMI <= 34.9:
    print("중등도 비만")
else:
    print("고도비만")
# Out:
# 몸무게 : 50
# 키 : 160
# 정상체중

# %% [markdown]
# ### nested ```if``` statement
#
# * 하나의 조건을 검사한 후에, 또다른 조건을 검사해야 될 필요가 있을 수 있다.
# * 이러한 경우 중첩된 ```if``` 구문을 사용할 수 있다.
# * 하나의 ```if```문 혹은 ```else```문 내에 또다른 ```if```,```else``` 구문이 나타날 수 있다.
#    * 마찬가지로 ```if```문 내에 ```if```문 내에 ```if```문이 등장할 수도 있다.
# * 최소값을 찾는 다음의 코드가 옳게 작동하는지 살펴 보고, 잘못된 부분이 있으면 개선하여 보자.

# %%
# x, y, z 중 서로 같은 값은 없다고 가정
x = 10
y = 5
z = 2
if x < y:
    if x < z:
        print("x is the least")
    else:
        print("z is the least")
else: print("y is the least")
# Out:
# y is the least

# %% [markdown]
# #### 예제2

# %%
#by s21910685 짝수인지 홀수인지 판별하는 문제
def even_odd(num):

    if num % 2 == 0:
        return "짝수"
    
    else:
        return "홀수"

num = int(input("입력하시오:"))
answer = even_odd(num)
print(answer)
# Out:
# 입력하시오:20
# 짝수

# %% [markdown]
# ## ```elif```을 통한 조건 추가
#
# ```elif``` 의 문법
#
# ```
# if expression1:
#   statement1(s)
# elif expression2:
#   statement2(s)
# elif expression3:
#   statement3(s)
# else:
#   statement4(s)
# ```
#
#
# * ```elif``` 문을 사용하면 여러 표현식을 검사하고, 조건 중 하나가 ```True```로 판정되는 코드 블록을 실행
# * ```else```와 마찬가지로 ```elif``` 프로그램의 목적에 따라 생략이 될 수 있음
# * 그러나 많아야 한 번 등장하는 ```else```와는 달리, ```if``` 다음에 임의의 수의 ```elif``` 문이 있을 수 있음

# %%
# x, y, z 중 서로 같은 값은 없다고 가정
x = 10
y = 5
z = 2
if x < y and x < z: print("x is the least")
elif y < z: print("y is the least")
else: print("z is the least")
# Out:
# z is the least

# %% [markdown]
# * ```if```문에서 ```and``` 를 이용하여 두 조건을 동시에 넣은 것에 주의
# * ```if```의 조건에 해당하지 않으면 (x가 최소값이 아니라면), 두 번째 조건이 ```elif``` 뒤에 명시되는 것을 확인

# %% [markdown]
# <p> &#9635 <code>elif</code> 를 이용한 예제 1 </p>

# %%
x = 123
if x < 10:
    print('one digit number')
elif x < 100:
    print('two digit number')
elif x < 1000:
    print('three digit number')
else:
    print('large number')
# Out:
# three digit number

# %% [markdown]
# 위 코드를 ```elif```없이 작성한다면 어떻게 될까?

# %% [markdown]
# <p> &#9635 <code>elif</code> 를 이용한 예제 2 </p>
# 다음의 예제는 ```elif```을 사용하여 보다 간단하게 작성할 수 있다. 스스로 작성하여 보자.

# %%
x = 15
if x%2 == 0:
    if x%3 == 0:
        print('Divisible by 2 and 3')
    else:
        print('Divisible by 2 and not by 3')
else:
    if x%3 == 0:
        print('Divisible by 3 and not by 2')
    else:
        print('Not divisible by both of 2 and 3')
# Out:
# Divisible by 3 and not by 2

# %% [markdown]
# 점수에 따라 학점을 부여하는 예제

# %%
#by s22210620
score = int(input("국어 점수:"))
if 0<=score<=100: #if 조건:
    print(f"입력한 점수는 {score}입니다.")
    if score>=90:
        print("A")
    elif score>=80:
        print("B")
    elif score>=70:
        print("C")
    elif score>=60:
        print("D")
    else:
        print("F")
else:
    ㅔrint("범위를 벗어난 점수를 입력하였습니다.")

# %% [markdown]
# ### Inline ```if-else``` statements
# Python은 다음과 같이 ```if else```를 한 라인에 작성할 수 있도록 지원한다. 순서에 주의하여 살펴보자.

# %%
a = 37
y = "large" if a ** 2 > 1000 else "small"
print(y)
# Out:
# large

# %% [markdown]
# 위 코드는 아래 코드와 같다.

# %%
a = 37
if a ** 2 > 1000: y = "large"
else: y = "small"
print(y)
# Out:
# large

# %% [markdown]
# #### MBTI 예제

# %%
#by_22210607
mbti = input("mbti를 입력하세요:")
if mbti[-2].lower() == "T" or mbti[-2].lower() == "t":
    print("너 T야?")
else:
    print("아? 아니구나??!!! 난 또...T인 줄...알고")
# Out:
# mbti를 입력하세요:infj
# 아? 아니구나??!!! 난 또...T인 줄...알고

# %% [markdown]
# ## 연습문제
#
# 다음의 연습문제들은 2, 3, 4 단원의 내용만을 이용하여 작성해 보라.
#
# * 정수인 변수가 주어졌을 때, 홀수(odd)인지 짝수(even)인지 판별하는 프로그램을 작성하라.

# %% [markdown]
# * 월(month)이 대입된 정수인 변수가 주어졌을 때, 해당 월이 며칠인지 출력하는 프로그램을 작성하라.

# %% [markdown]
#  * x, y, z의 세 개의 변수가 있다. 이 세 변수를 검사하여 가장 큰 홀수를 프린트하라. 만약 세 변수가 모두 홀수가 아니라면, 홀수가 없다는 메시지를 출력하라.

# %% [markdown]
#  * 삼각형 세 변의 길이가 변수로 주어졌을 때, 정삼각형(Equilateral triangle), 이등변삼각형(Isosceles triangle), 일반삼각형(triangle)을 구분하는 프로그램을 작성하라.

# %% [markdown]
# * 삼각형 세 변의 길이가 변수로 주어졌을 때, 직각 삼각형인지 아닌지 판단하는 프로그램을 작성하라.

# %% [markdown]
# * 두 자리 정수가 대입된 변수를 검사하여, 십의 자리 숫자와 일의 자리 숫자의 합이 10이 넘는지 판단하는 프로그램을 작성하라.

# %% [markdown]
# * 13자리 숫자가 ISBN 13자리 코드의 원칙에 맞는지 판단하는 프로그램을 작성하라.
#   * ISBN코드가 abcdefghijklm일 때, $a+3b+c+3d+e+3f+g+3h+i+3j+k+3l+m$이 10으로 나누어 떨어져야 한다.

# %% [markdown]
# * 해(year)가 윤년인지를 판단하는 프로그램을 작성하라. 윤년의 규칙은 다음과 같다.
#   * 서력 기원 연수가 4로 나누어 떨어지는 해는 윤년으로 한다.(1988년, 1992년, 1996년, 2004년, 2008년, 2012년 …)
#   * 이 중에서 100으로 나누어 떨어지는 해는 평년으로 한다.(1900년, 2100년, 2200년, 2300년, 2500년 …)
#   * 그중에 400으로 나누어 떨어지는 해는 윤년으로 둔다.

# %% [markdown]
# * 문자열 변수를 검사하여, 마지막 글자가 모음(a, e, i, o, u, A, E, I, O, U)으로 끝나는지 아닌지 판단하는 프로그램을 작성하라.

# %% [markdown]
# * 문자열 변수를 검사하여, 첫 글자와 마지막 글자가 같은지 검사하는 프로그램을 작성하라. 대소문자는 구분하지 않는다. 즉, Mom은 첫 글자와 마지막 글자가 같은 단어로 간주한다.

# %% [markdown]
# * 두 문자열 변수를 검사하여, 첫 글자끼리 서로 같은지 검사하는 프로그램을 작성하라. 대소문자는 구분하지 않는다.

# %% [markdown]
# * 0 이상 100 이하의 값이 입력된 변수를 검사하여, grade를 정하는 프로그램을 작성하라. 규칙은 다음을 따른다.
#
#   * 95 이상 : A+
#   * 90 이상 95 미만 : A
#   * 85 이상 90 미만 : B+
#   * 80 이상 85 미만 : B
#   * 그 외의 점수 : C

# %% [markdown]
# * 몸무게, 키, 성별이 저장된 변수를 조사하여 비만도를 체크하는 프로그램을 작성하라. 비만도 기준은 다음의 자료를 이용하라.
# http://health.cdc.go.kr/health/mobileweb/content/group_view.jsp?CID=XUNT32FT6B

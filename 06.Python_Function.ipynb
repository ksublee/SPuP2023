# %% [markdown]
# # 6. 함수
# ---------

# %% [markdown]
# ## 함수 (function) 개요
# ------
#
# * 함수는 하나의 관련 작업을 수행하는 데 사용되는 재사용 가능한 코드 블록이다.
#   * 함수는 응용 프로그램의 모듈성을 높이고 코드 재사용 수준을 높인다.
# * Python은 기본적으로 많은 내장 함수를 제공한다.
# * 문자열 등을 다루면서 함수를 사용한 경험을 상기해 보자.
#   * ```len("Python programming")```
# * 필요에 따라 함수를 생성하여 원하는 기능을 따로 분리하여 사용하는 법을 익혀보자.
#   * Python에서 제공하는 함수 뿐만 아니라 사용자 정의의 새로운 함수를 만드는 법.
#
# <p> <font color=#00008B> &#9635 Decomposition </font> -
# 복잡한 문제나 시스템을 더 작고 관리하기 쉬운 부분이나 하위 작업으로 나누는 것을 말하며, 문제 해결 프로세스를 단순화하고 더 체계적으로 만들 수 있다. </p>
#
# <p> <font color=#00008B> &#9635 Abstraction </font> -
#  작업 수행 방법에 대한 정확한 세부 정보를 직접 보여 주기보다는 특정 기능을 수행하도록 이미 정의된 함수를 사용하게 하고, 이를 통해 함수를 블랙 박스처럼 취급할 수 있으며 기본 구현에 대해 걱정할 필요 없이 쉽게 사용하고 재사용할 수 있게 한다.

# %% [markdown]
# ### 함수 정의의 규칙
#
# * 함수 블록은 키워드 ```def```와 함수 이름 및 괄호```()```로 시작한다.
#
# * 모든 입력 매개 변수는 괄호 안에 있어야 한다. 이 괄호 안에 매개 변수를 정의할 수도 있다.
#
# * 모든 함수 내의 코드 블록은 콜론(```:```)으로 시작되고 들여쓰기를 하여야 한다.
#
# * ```return expression``` 명령문은 함수를 종료하고 호출자에게 결과를 전달한다.
#
# ```
# def function_name(< argument >):
#    < something to do >
# ```

# %% [markdown]
# <p> <font color=#00008B> &#9635 반환 (return) </font> - 함수가 해야할 일을 모두 마치고 최종적인 값을 전달하여, 그 결과를 프로그램의 다른 곳에서 활용할 수 있도록 하는 것 </p>

# %% [markdown]
# <p> &#9635 예제: 제곱 후 1을 더해서 반환하는 함수 </p>

# %%
def square_plus_one(x):
    ans = x ** 2 + 1
    return ans

# %% [markdown]
# <img src="data:image/png;base64,..." width="400" alt="" />

# %% [markdown]
#  * 함수는 인자(argument)를 입력 받아 ```x```라는 매개 변수(parameter)에 대입
#  * ```x**2 + 1``` 의 계산을 수행한 후
#  * 결과를 ```ans```에 대입하여 반환(return)하고 있음
#    * `return`을 수행하면 함수는 자동적으로 종료된다.

# %% [markdown]
# 함수의 정의되면, 정의된 함수를 호출하여 계산을 할 수 있다.
#    * ```square_plus_one(10)``` 등을 수행해 보자.
#    * 10이라는 인자를 입력 받아 ```x```라는 매개 변수에 대입하여 계산을 수행한 후 결과를 전달한다.

# %%
square_plus_one(10)
# Out:
# 101

# %% [markdown]
# <p> &#9635 예제: 제곱근 반환 함수 </p>

# %%
def my_sqrt(x):
    ans = 0
    increment = 1
    while increment >= 0.0001:
        ans += increment
        if ans**2 == x:
            break
        elif ans**2>x:
            ans -= increment
            increment = increment/10.0
    return ans

# %% [markdown]
# ### 함수 호출하기
#
# 함수를 정의하였으면 이를 호출하여 활용할 수 있음

# %%
print(my_sqrt(2))
# Out:
# 1.4142

# %%
y = 16 
print(my_sqrt(y))
# Out:
# 4

# %%
z = 12 
print(my_sqrt(z*12))
# Out:
# 12

# %%
x = my_sqrt(100) 
print(x*x)
# Out:
# 100

# %% [markdown]
# ### ```return```과 ```print```
#
# * 함수를 처음 접하는 경우 ```return```과 ```print```의 개념을 혼동하는 경우가 많다.
# * 이는 Jupyter notebook 등에서 함수를 실행할 때, return 값을 자동으로 화면에 출력하도록 하기 때문이다.
# * 실제로는 둘은 전혀 다른 개념이므로 절대로 혼동하지 않도록 한다.
# * ```return```의 궁극적인 목적은 함수의 계산 결과를 반환하여 이차적으로 활용할 수 있도록 하는 것이고,
# * ```print```는 단순히 화면에 출력하여 프로그래머가 눈으로 값을 확인할 수 있게 한다.
#   * 함수 내에서 사용되는 ```print```는 함수 본체 중의 일부일 뿐이다.
#
# 다음 두 함수를 비교해 보자.

# %%
def this_func_print(x):
    print(x ** 2 + 1)

def this_func_return(x):
    return x ** 2 + 1

# %% [markdown]
# 단순히 함수를 실행시켰을 경우, Jupyter notebook이나 콘솔에서의 실행 결과는 비슷해 보인다.

# %%
this_func_print(2)
# Out:
# 5

# %%
this_func_return(2)
# Out:
# 5

# %% [markdown]
# 하지만, ```this_func_return```의 결과는 다른 변수에 할당하여, 이차적으로 활용할 수 있는 반면, ```this_func_print```는 그렇지 않다.

# %%
y = this_func_return(2) # this_func_return(2)의 결과 5가 y에 대입된다.
print(y / 10)           # y를 다른 계산에 활용할 수 있다. 5/10 = 0.5
# Out:
# 0.5

# %% [markdown]
# ```this_func_print```의 ```return```은 존재하지 않으며, python에서는 이를 ```None```이라는 값으로 처리한다.
# 따라서 다음 코드에서 ```y```의 값은 ```None```에 불과하며 이를 이차적으로 활용할 방안은 많지 않다.

# %%
y = this_func_print(2)   # this_func_print(2) 결과는 5로 정상 출력되지만
print(y)                 # y는 None으로 큰 의미가 없음, 즉 다른 계산에 활용할 수 없다.
# Out:
# 5
# None

# %% [markdown]
# ## 매개 변수 (parameter)와 인자 (argument)
# --------------
#
# 매개 변수와 인자는 혼용되어 사용될 수 있으나, 매개변수는 함수 정의에서 괄호 안에 나열된 변수를 의미하고, 인수는 함수가 호출될 때 함수로 전송되는 값을 나타낸다.

# %% [markdown]
# ### 매개 변수가 없는 함수
# * 어떤 함수는 아무런 인자를 받지 않을 수 있으며 이에 따라 아무런 매개 변수가 정의되지 않는다.
# * 빈 괄호 ()로 표현된다.

# %%
def print_something():
    print("This function does nothing.")

# %% [markdown]
# * 위 함수는 아무런 인자를 받지 않을 뿐만 아니라, 아무런 반환값도 없음 (```None```을 반환)
#   * ```return```을 찾을 수 없다.
#   * ```print_something()``` 함수를 실행해 보자.

# %%
print_something()
# Out:
# This function does nothing.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>에러:</b>
#     인자가 필요하지만 함수 호출 시 입력하지 않았을 경우 에러가 발생한다.
# </div>

# %%
def printme(stri):
    print("Input is :", stri)
    return

printme() # 인자를 입력하지 않았음
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       2     print("Input is :", stri)
#       3     return
# ----> 5 printme()
#
# TypeError: printme() missing 1 required positional argument: 'stri'

# %% [markdown]
# * 다음과 같이 인자가 어떤 값을 입력받는지 확실히 표현할 수도 있다.
#   * ```(stri = "My string") ```이라고 표현한 것에 주목하자.

# %%
def printme(stri):
    print("Input is :", stri)
    return


printme(stri = "My string")
# Out:
# Input is : My string

# %% [markdown]
# ### 여러 개의 인자를 받는 함수
#
# * 함수는 여러 개의 인자를 받을 수 있으며, 대응되는 매개 변수들의 리스트가 괄호 안에 표현된다.

# %%
def printinfo(name, age):
    print("Name: ", name)
    print("Age: ", age)
    return

printinfo(age=50, name="miki")
# Out:
# Name:  miki
# Age:  50

# %%
def my_max(x, y):
    if x >= y:
          return x
    else:
          return y

# %%
my_max(10,12)
# Out:
# 12

# %%
def printName(firstName, lastName, reverse):
    if reverse:
          print(lastName + ', ' + firstName)
    else:
          print(firstName, lastName)

# %% [markdown]
# 다음의 표현은 동치이다.

# %%
printName('Kyungsub', 'Lee', False)
printName('Kyungsub', 'Lee', reverse=False)
printName(lastName='Lee', firstName='Kyungsub', reverse=False)
# Out:
# Kyungsub Lee
# Kyungsub Lee
# Kyungsub Lee

# %% [markdown]
# ### 최대공약수를 구하는 함수

# %%
def my_GCD(x, y):
    j = 1
    ans = 1
    while j <= x and j <= y:
        if x%j == 0 and y%j == 0:
            ans = j
        j += 1
    return ans

# %%
my_GCD(24, 84)
# Out:
# 12

# %% [markdown]
# 최소공배수를 구하는 함수도 만들어 보자.

# %% [markdown]
# ### Default parameter
#
# * 함수 생성 시 다음과 같이 default parameter를 설정할 수 있다.
# * default parameter는 입력값이 따로 없을 때, 함수 정의 단계에서 `=`를 통해 미리 설정된 default값을 이용한다.

# %%
def printName(firstName, lastName, reverse = False):
    if reverse:
         print(lastName + ', ' + firstName)
    else:
         print(firstName, lastName)
            
printName('Kyungsub', 'Lee')
# Out:
# Kyungsub Lee

# %%
printName('Kyungsub', 'Lee', True)
# Out:
# Lee, Kyungsub

# %%
def printinfo(name, age = 35):  # age = 35로 default 설정 되어 있음
    print("Name: ", name)
    print("Age: ", age)
    return

# %%
printinfo(age=50, name="miki")
printinfo(name="miki" )    # age = 35의 default 값을 이용
# Out:
# Name:  miki
# Age:  50
# Name:  miki
# Age:  35

# %% [markdown]
# ## Scope
# --------------

# %% [markdown]
# ### 지역 변수(local variable)
#
# * 함수 내의 변수는 함수 내에서만 존재하는 변수

# %%
def my_func():
    x = 20     # 지역 변수 x
    
x = 10         # 전역 변수 x
my_func()
print(x)
# Out:
# 10

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>주의:</b>  함수 내의 지역 변수와 함수 바깥의 전역 변수(global variable)는 서로 다른 것이다. </div>

# %%
def my_func():
    x = 20
    return x

x = 10
x = my_func()
print(x)
# Out:
# 20

# %%
def increase(x):
    x = x + 1
    
x=1
increase(x)
print(x)
# Out:
# 1

# %%
def increase(x):
    x = x + 1
    return x

x = 1
x = increase(x)
print(x)
# Out:
# 2

# %% [markdown]
# ###  변수 scope 더 살펴보기
#
# 변수의 scope는 해당 변수가 파이썬 인터프리터에게 보이거나 액세스 가능한 범위를 나타낸다.
#
# 다음의 예제에서 변수 ```x```는 함수 내에 존재하지 않기 때문에, 함수 바깥에서 정의된 ```x```의 값을 가져온다.

# %%
x = 1
def print_x():
    print(x)
    
print_x()
# Out:
# 1

# %% [markdown]
# 다음은 함수 밖에 ```x```가 정의되어 있어 있지만, 함수 내에서 ```x```가 다시 정의되다.
# 이 경우 함수 내에서 ```x```를 사용할 때는, 함수 내에서 정의된 ```x```가 우선 순위를 가진다.

# %%
x = 1
def print_x():
    x = 2
    print(x)
    
print_x()
# Out:
# 2

# %% [markdown]
# Python은 어디서 name definition이 발생하는지, 어디서 해당 이름이 참조되는지에 따라 scope를 결정한다.
#
# * local : 함수 내부에서 ```x```를 참조하는 경우 파이썬 인터프리터는 먼저 해당 함수에 로컬인 가장 안쪽 범위에서 ```x```를 탐색한다.
#
# * enclosing : ```x```가 로컬 범위에 없지만 다른 함수 내부에 있는 함수에 나타나면 파이썬 인터프리터는 바깥쪽 함수의 scope에서 탐색한다.
#
# * global : 위의 검색 중 어느 것에도 해당 변수가 정의되지 않았으면, 파이썬 인터프리터는 다음에 전역 범위를 찾는다.
#
# * built-in : 위의 검색 중  ```x```를 찾을 수 없으면 인터프리터는 built-in scope에서 찾는다.

# %%
# global scope
x = 0
def outer():
    # enclosing scope
    x = 1
    def inner():
        # local scope
        x = 2

# %% [markdown]
# ## 농장 문제
#
# * 농장에 돼지들과 닭들이 있다. 총 머리의 수는 20개, 총 다리의 수는 56개이다. 돼지와 닭의 수는 각각 얼마인가?
#  * Brute force 방법으로 풀어보자.

# %%
for x in range(0,21):
    y = 20 - x
    if 4*x + 2*y == 56:
         break
print(x, y)
# Out:
# 8 12

# %% [markdown]
# ### 농장 문제 – 함수
#
# * 임의의 머리 수와 다리 수가 주어졌을 때, 돼지와 닭의 수를 구하는 함수를 작성해 보자.

# %%
def farm(numHeads, numLegs):
    for x in range(0, numHeads + 1):
        y = numHeads - x
        if 4*x + 2*y == numLegs:
              return x, y

# %%
print(farm(20, 56))
# Out:
# (8, 12)

# %%
print(farm(20, 60))
# Out:
# (10, 10)

# %% [markdown]
# ### `None`
#
# * Python에서 없는 값을 나타내기 위해 사용되는 값
# * None을 이용하여 해가 없는 경우를 대비하여 보자.

# %%
def farm(numHeads, numLegs):
    for x in range(0, numHeads + 1):
        y = numHeads - x
        if 4*x + 2*y == numLegs:
            return x, y
    return None, None

farm(100,10)
# Out:
# (None, None)

# %% [markdown]
# * 앞의 예제에서 return이 두 번 등장함을 볼 수 있음
#    * 첫 번째 return은 방정식의 조건이 만족하면 다리의 숫자를 return하고 함수를 종료
#    * 두 번째 return은 방정식의 조건을 만족하는 해가 없을 때 None을 반환

# %% [markdown]
# ### 함수를 호출하는 함수

# %%
def farm_UI():
    heads = int(input('Enter the number of heads : '))
    legs = int(input('Enther the number of legs : '))
    pigs, chickens = farm(heads, legs)
    if pigs == None:
        print('No solution')
    else:
        print('Number of pigs : ', pigs)
        print('Number of chickens : ', chickens)
        
farm_UI()
# Out:
# Enter the number of heads :  7
# Enther the number of legs :  18
# Number of pigs :  2
# Number of chickens :  5

# %% [markdown]
# ## 그 외에 알아둘 점

# %% [markdown]
# ### Built-in function
#
# * Python에 이미 내장되어 있는 built-in function들을 활용할 수 있음
#
# * https://docs.python.org/3/library/functions.html
#
# * ```range()```, ```str()```, ```raw()```, ```len()```, …
#
# * ```max()```, ```min()```, ```abs()```, ```type()```, …

# %% [markdown]
# ### ```lambda```
#
# ```lambda```는 비교적 간단한 함수를 생성할 때 사용하는 키워드로 ```def```와 비슷한 역할을 한다.
#
# 문법은 다음과 같다.
#
# ```lambda arguments: expression```

# %%
def my_add_plus_one1(x, y): return x + y + 1

# %% [markdown]
# 위 함수 정의는 다음의 방법으로 거의 똑같이 구현할 수 있다.
# * ```lambda```와 ```:``` 사이에 parameter들이 오며, ```:```뒤에 return값을 배치한다.

# %%
my_add_plus_one2 = lambda x, y: x + y + 1

# %%
my_add_plus_one2(1, 2)
# Out:
# 4

# %% [markdown]
# ```lambda``` 방법의 장점은 함수에 특별히 이름을 붙이지 않아도 함수를 사용가능 하도록 한다는 점이다.
#  * 이를 anonymous function이라고도 부른다.

# %%
(lambda x, y: x + y + 1)(1, 2)
# Out:
# 4

# %% [markdown]
# 여기서 바로 활용해 보지는 않지만, 함수를 인자로 전달하는 경우 자주 활용된다.

# %% [markdown]
# ## Module
#
# <p> <font color=#00008B> &#9635 모듈 </font> - 모듈은 비슷한 역할을 담당하는 코드들을 모아 놓은 추가적인 파이썬 파일로, 현재 프로그램으로 import하여 사용할 수 있다.</p>
#
# * 기본적으로 제공하는 Built-in function 외에도 module을 통하여 다양한 함수 제공
#
# * 예
#   * math 모듈
#     * 기본적인 수학 연산을 도와주는 모듈
#     * https://docs.python.org/3/library/math.html
#   * random 모듈
#     * 다양한 분포에 대한 random number를 활용할 수 있게 해주는 모듈
#     * https://docs.python.org/3/library/random.html
#
# * `import` 명령을 사용하여 모듈을 불러와 사용

# %% [markdown]
# ### [Math module](https://docs.python.org/3/library/math.html)
#
# * ```import math```
# * ```math.sqrt(x)```
#   * x의 제곱근 반환
# * ```math.exp(x)```
#   * e**x 반환
# * ```math.sin(x)```
#   * sin 함수값 반환
# * ```math.pi```
#   * 3.141592…

# %%
import math
math.sqrt(71)
# Out:
# 8.426149773176359

# %%
math.sin(math.pi / 2)
# Out:
# 1.0

# %%
math.log(4) / math.log(2)
# Out:
# 2.0

# %%
math.log(4) % math.log(2)
# Out:
# 0.0

# %%
math.log(8) / math.log(2)
# Out:
# 3.0

# %%
# 실수 간의 나머지를 계산할 때는 주의하여야 한다.
math.log(8) % math.log(2)
# Out:
# 0.6931471805599452

# %% [markdown]
# ### [Random module](https://docs.python.org/3/library/random.html)
#
# * ```import random```
# * ```random.random()```
#   * 0이상 1이하의 랜덤값 반환
# * ```random.uniform(a,b)```
#   * a이상 b이하에서 uniform 분포를 가지는 랜덤값 반환
# * ```random.randint(a,b)```
#   * a이상 b이하의 랜덤 정수 반환
# * ```random.gauss(mu, sigma)```, ```random.normalvariate(mu, sigma)```
#   * 평균 mu, 표준편차 sigma의 정규 분포를 가지는 랜덤값 반환

# %%
import random
random.random()
# Out:
# 0.5306616346508001

# %%
random.uniform(0, 10)
# Out:
# 7.364816301962892

# %%
random.randint(1, 5)
# Out:
# 4

# %%
random.gauss(0, 1)
# Out:
# -0.4658854780176727

# %% [markdown]
# <p> &#9635 예제 : 랜덤 숫자를 맞추는 프로그램 </p>
#
# 1부터 100까지의 숫자를 랜덤으로 생성 후 키보드 입력을 통해 그 숫자를 맞추는 프로그램

# %%
import random
def guess():
    a = random.randint(1, 100)
    while(True):
        x = input("Guess the number between 1 to 100 (type q to quit) : ")
        
        if x == "q":
            return
        elif a == int(x):
            print("Correct!")
            return
        elif a < int(x):
            print("The number is smaller than your guess, try again.")
        elif a > int(x):
            print("The number is larger than your guess, try again.")
        else:
            print("Please input appropriate number.")

# %%
guess()
# Out:
# Guess the number between 1 to 100 (type q to quit) :  50
# The number is larger than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  75
# The number is smaller than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  62
# The number is larger than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  69
# The number is smaller than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  65
# The number is larger than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  67
# The number is larger than your guess, try again.
# Guess the number between 1 to 100 (type q to quit) :  68
# Correct!

# %% [markdown]
# #### t – 랜덤 변수
#
# * `gauss()` 함수와 `gammavariate()` 함수를 이용하여 t-분포를 따르는 랜덤 변수를 생성하는 함수

# %%
import math 
import random

def student_t(nu): # nu equals number of degrees of freedom
    x = random.gauss(0.0, 1.0)
    y = 2.0*random.gammavariate(0.5*nu, 2.0)
    return x / (math.sqrt(y/nu))

# %%
student_t(10)
# Out:
# -0.9651852373336636

# %% [markdown]
# ### 모듈 파일을 불러오는 다양한 방법

# %%
import random  
random.randint(1, 10)
# Out:
# 5

# %%
from random import *  
randint(1, 10)
# Out:
# 10

# %%
import random as r   
r.randint(1, 10)
# Out:
# 5

# %% [markdown]
# ### 모듈에 대한 여러 가지
#
# * 파이썬 스크립트 파일로 개인적으로 모듈을 만들어 사용할 수 있다.
#   * 기본 작업 directory에 저장하여 import 할 수 있음
#   * ```import fibo```
# * 모듈 변경과 갱신
#   * 혹시 모듈을 변경하였다면 ```reload``` 명령을 이용하여 갱신
#    * ```from imp import reload```
#    * ```reload(fibo)```

# %%
import fibo
fibo.fib(50)
# Out:
# 1, 1, 2, 3, 5, 8, 13, 21, 34,
